# %% [markdown]
# # 데이터 검증(Data validation)
#
# 1. 무엇을 하는 단계인가:
#   - 이상치 검출
#   - 스키마 변경 감지
#   - 데이터 드리프트를 유발시키는 데이터셋 간(train-eval, span ver1-ver2 etc.) 통계 변경 감지
#
# 2. TFDV(TensorFlow Data Validation)
#   - TFDV의 시각화는 [Facet](https://pair-code.github.io/facets/) 프로젝트에 기반
#   - TFDV가 받아들일 수 있는 파일 입력 형식은 CSV와 TFRecord 두 가지(메모리 상 객체론 ExampleGen이 생성한 아티팩트를 파이프라인 다음 단계로서 받아들인다)

# %%
import os

import pandas as pd
import tensorflow_data_validation as tfdv
# 관심 슬라이스(SQL `GROUP BY` 같은 거)별로 데이터셋을 묶기 위한 유틸.
from tensorflow_data_validation.utils import slicing_util
from tensorflow_metadata.proto.v0 import statistics_pb2 as stats_pb2
# 머신러닝 파이프라인 일부로서 데이터 검증을 위한 컴포넌트들
from tfx.components import (ImportExampleGen, StatisticsGen, SchemaGen,
                            ExampleValidator,)
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext

# %%
data_dir = os.path.join(os.getcwd(), "data")
complaints_dir = os.path.join(data_dir, "complaints")
raw_path = os.path.join(complaints_dir, "consumer-complaints.tfrecord")
processed_path = os.path.join(complaints_dir, "processed", "processed-complaints.csv")

# %%
df = pd.read_csv(processed_path)

# %%
df.head()
# Out:
#   Date received       Product                     Sub-product  \
# 0    2016-05-09      Mortgage     Conventional fixed mortgage
# 1    2016-06-01      Mortgage     Conventional fixed mortgage
# 2    2017-04-18      Mortgage                    FHA mortgage
# 3    2017-04-17  Student loan  Federal student loan servicing
# 4    2017-04-21  Student loan        Non-federal student loan
#
#                                       Issue  \
# 0  Loan servicing, payments, escrow account
# 1  Loan servicing, payments, escrow account
# 2  Loan modification,collection,foreclosure
# 3        Dealing with my lender or servicer
# 4        Dealing with my lender or servicer
#
#                                Sub-issue  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3  Having problems with customer service
# 4  Trouble with how payments are handled
#
#                         Consumer complaint narrative  \
# 0  XXXX of XXXX complaints regarding same company...
# 1  My Mortgage Company, Ditech, failed to apply p...
# 2  My husband and I are going through a financial...
# 3  In XX/XX/2016 I contacted ACS regarding incorr...
# 4  This complaint is further evidence tha t Navie...
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
# 1  Company believes complaint is the result of an...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    Company State  ZIP code Tags  \
# 0  Specialized Loan Servicing Holdings LLC    CA     95472  NaN
# 1                     Ditech Financial LLC    SC     29414  NaN
# 2             PENNYMAC LOAN SERVICES, LLC.    AZ     85338  NaN
# 3                   ACS Education Services    CA     92223  NaN
# 4                  Navient Solutions, LLC.    TX     78746  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web           2016-05-09
# 1           Consent provided           Web           2016-06-01
# 2           Consent provided           Web           2017-04-18
# 3           Consent provided           Web           2017-04-17
# 4           Consent provided           Web           2017-04-21
#
#   Company response to consumer Timely response?  Consumer disputed?  \
# 0      Closed with explanation              Yes                   0
# 1      Closed with explanation              Yes                   1
# 2      Closed with explanation              Yes                   0
# 3      Closed with explanation              Yes                   0
# 4      Closed with explanation              Yes                   0
#
#    Complaint ID
# 0       1915601
# 1       1950363
# 2       2440537
# 3       2438881
# 4       2446956

# %%
# TODO(me): `generate_statistics_from_csv` 메소드 실행 시 서버 주피터 커널이 자꾸 재시작하는 문제
# stats = tfdv.generate_statistics_from_csv(
#     data_location=processed_path,  # ExampleGen과 달리 단일 파일을 지정해야 함을 헷갈리지 말 것.
#     delimiter=','
# )

# tfrecord 피처명은 processed-complaints.csv에 있는 피처명을 소문자화,
# 공백은 밑줄로 처리하고, 일부 단어를 생략한 피처명이므로 데이터프레임 대신 tfrecord를 읽었다.
full_records = os.path.join(complaints_dir, "records",
                            "consumer-complaints.tfrecord")
stats = tfdv.generate_statistics_from_tfrecord(data_location=full_records)
# Out:
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# WARNING:tensorflow:From /home/hakjun/projects/pipeline/venv/lib/python3.8/site-packages/tensorflow_data_validation/utils/statistics_io_impl.py:91: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /home/hakjun/projects/pipeline/venv/lib/python3.8/site-packages/tensorflow_data_validation/utils/statistics_io_impl.py:91: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
stats  # 각 피처에 대한 통계를 볼 수 있다.
# Out:
# datasets {
#   num_examples: 66657
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 66657
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 66657
#       }
#       unique: 2366
#       top_values {
#         value: "EQUIFAX, INC."
#         frequency: 4740.0
#       }
#       top_values {
#         value: "Experian Information Solutions Inc."
#         frequency: 3963.0
#       }
#       top_values {
#         value: "TRANSUNION INTERMEDIATE HOLDINGS, INC."
#         frequency: 3791.0
#       }
#       top_values {
#         value: "BANK OF AMERICA, NATIONAL ASSOCIATION"
#         frequency: 2923.0
#       }
#       top_values {
#         value: "WELLS FARGO & COMPANY"
#         frequency: 2922.0
#       }
#       top_values {
#         value: "CITIBANK, N.A."
#         frequency: 2662.0
#       }
#       top_values {
#         value: "Navient Solutions, LLC."
#         frequency: 2478.0
#       }
#       top_values {
#         value: "JPMORGAN CHASE & CO."
#         frequency: 2379.0
#       }
#       top_values {
#         value: "CAPITAL ONE FINANCIAL CORPORATION"
#         frequency: 1392.0
#       }
#       top_values {
#         value: "Ocwen Financial Corporation"
#         frequency: 1332.0
#       }
#       top_values {
#         value: "NATIONSTAR MORTGAGE"
#         frequency: 1189.0
#       }
#       top_values {
#         value: "SYNCHRONY FINANCIAL"
#         frequency: 1159.0
#       }
#       top_values {
#         value: "Ditech Financial LLC"
#         frequency: 1016.0
#       }
#       top_values {
#         value: "U.S. BANCORP"
#         frequency: 902.0
#       }
#       top_values {
#         value: "AMERICAN EXPRESS COMPANY"
#         frequency: 731.0
#       }
#       top_values {
#         value: "ENCORE CAPITAL GROUP INC."
#         frequency: 721.0
#       }
#       top_values {
#         value: "PORTFOLIO RECOVERY ASSOCIATES INC"
#         frequency: 652.0
#       }
#       top_values {
#         value: "DISCOVER BANK"
#         frequency: 568.0
#       }
#       top_values {
#         value: "AES/PHEAA"
#         frequency: 567.0
#       }
#       top_values {
#         value: "Paypal Holdings, Inc"
#         frequency: 485.0
#       }
#       avg_length: 25.009857177734375
#       rank_histogram {
#         buckets {
#           label: "EQUIFAX, INC."
#           sample_count: 4740.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "Experian Information Solutions Inc."
#           sample_count: 3963.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "TRANSUNION INTERMEDIATE HOLDINGS, INC."
#           sample_count: 3791.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "BANK OF AMERICA, NATIONAL ASSOCIATION"
#           sample_count: 2923.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "WELLS FARGO & COMPANY"
#           sample_count: 2922.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "CITIBANK, N.A."
#           sample_count: 2662.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "Navient Solutions, LLC."
#           sample_count: 2478.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "JPMORGAN CHASE & CO."
#           sample_count: 2379.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "CAPITAL ONE FINANCIAL CORPORATION"
#           sample_count: 1392.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "Ocwen Financial Corporation"
#           sample_count: 1332.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "NATIONSTAR MORTGAGE"
#           sample_count: 1189.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "SYNCHRONY FINANCIAL"
#           sample_count: 1159.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "Ditech Financial LLC"
#           sample_count: 1016.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "U.S. BANCORP"
#           sample_count: 902.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "AMERICAN EXPRESS COMPANY"
#           sample_count: 731.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "ENCORE CAPITAL GROUP INC."
#           sample_count: 721.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "PORTFOLIO RECOVERY ASSOCIATES INC"
#           sample_count: 652.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "DISCOVER BANK"
#           sample_count: 568.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "AES/PHEAA"
#           sample_count: 567.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "Paypal Holdings, Inc"
#           sample_count: 485.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "ERC"
#           sample_count: 466.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "PNC Bank N.A."
#           sample_count: 436.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "BARCLAYS BANK DELAWARE"
#           sample_count: 411.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "Santander Consumer USA Holdings Inc."
#           sample_count: 398.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "SELECT PORTFOLIO SERVICING, INC."
#           sample_count: 393.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "TRANSWORLD SYSTEMS INC"
#           sample_count: 363.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "Seterus, Inc."
#           sample_count: 356.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "TD BANK US HOLDING COMPANY"
#           sample_count: 355.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "ALLY FINANCIAL INC."
#           sample_count: 349.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "UNITED SERVICES AUTOMOBILE ASSOCIATION"
#           sample_count: 343.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "Specialized Loan Servicing Holdings LLC"
#           sample_count: 333.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "SUNTRUST BANKS, INC."
#           sample_count: 332.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "HSBC NORTH AMERICA HOLDINGS INC."
#           sample_count: 332.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "Caliber Home Loans, Inc."
#           sample_count: 265.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "BB&T CORPORATION"
#           sample_count: 264.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "AFNI INC."
#           sample_count: 249.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "Diversified Consultants, Inc."
#           sample_count: 243.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "CARRINGTON MORTGAGE SERVICES, LLC"
#           sample_count: 238.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "Empowerment Ventures, LLC"
#           sample_count: 235.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "NAVY FEDERAL CREDIT UNION"
#           sample_count: 231.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "Convergent Resources, Inc."
#           sample_count: 231.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "Freedom Mortgage Company"
#           sample_count: 215.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "FIFTH THIRD FINANCIAL CORPORATION"
#           sample_count: 209.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "Nelnet, Inc."
#           sample_count: 208.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "LoanCare, LLC"
#           sample_count: 205.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "CITIZENS FINANCIAL GROUP, INC."
#           sample_count: 196.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "Resurgent Capital Services L.P."
#           sample_count: 194.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "Rocket Mortgage, LLC"
#           sample_count: 186.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "I.C. System, Inc."
#           sample_count: 180.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "Shellpoint Partners, LLC"
#           sample_count: 176.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "Community Loan Servicing, LLC (formerly known as Bayview Loan Servicing, LLC)"
#           sample_count: 174.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "TENET HEALTHCARE CORPORATION"
#           sample_count: 172.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "REGIONS FINANCIAL CORPORATION"
#           sample_count: 172.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "National Credit Systems,Inc."
#           sample_count: 172.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "Big Picture Loans, LLC"
#           sample_count: 171.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "Commonwealth Financial Systems, Inc."
#           sample_count: 158.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "ONEMAIN FINANCIAL HOLDINGS, LLC."
#           sample_count: 157.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "M&T BANK CORPORATION"
#           sample_count: 156.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "SLM CORPORATION"
#           sample_count: 152.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "PENNYMAC LOAN SERVICES, LLC."
#           sample_count: 151.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "SCOTTRADE BANK"
#           sample_count: 148.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "PHH Mortgage Services Corporation"
#           sample_count: 143.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "Fidelity National Information Services, Inc. (FNIS)"
#           sample_count: 143.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "BBVA FINANCIAL CORPORATION"
#           sample_count: 142.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "KEYCORP"
#           sample_count: 139.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "HW Holding, Inc"
#           sample_count: 135.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "Southwest Credit Systems, L.P."
#           sample_count: 131.0
#         }
#         buckets {
#           low_rank: 67
#           high_rank: 67
#           label: "Pinnacle Credit Services, LLC"
#           sample_count: 126.0
#         }
#         buckets {
#           low_rank: 68
#           high_rank: 68
#           label: "CCS Financial Services, Inc."
#           sample_count: 126.0
#         }
#         buckets {
#           low_rank: 69
#           high_rank: 69
#           label: "Conn\'s, Inc."
#           sample_count: 125.0
#         }
#         buckets {
#           low_rank: 70
#           high_rank: 70
#           label: "MONEYGRAM PAYMENT SYSTEMS WORLDWIDE INC"
#           sample_count: 117.0
#         }
#         buckets {
#           low_rank: 71
#           high_rank: 71
#           label: "HUNTINGTON NATIONAL BANK, THE"
#           sample_count: 116.0
#         }
#         buckets {
#           low_rank: 72
#           high_rank: 72
#           label: "WESTERN UNION COMPANY, THE"
#           sample_count: 115.0
#         }
#         buckets {
#           low_rank: 73
#           high_rank: 73
#           label: "Populus Financial Group, Inc. (F/K/A Ace Cash Express)"
#           sample_count: 115.0
#         }
#         buckets {
#           low_rank: 74
#           high_rank: 74
#           label: "Bread Financial Holdings, Inc."
#           sample_count: 114.0
#         }
#         buckets {
#           low_rank: 75
#           high_rank: 75
#           label: "EOS Holdings, Inc."
#           sample_count: 111.0
#         }
#         buckets {
#           low_rank: 76
#           high_rank: 76
#           label: "Stellar Recovery, Inc."
#           sample_count: 103.0
#         }
#         buckets {
#           low_rank: 77
#           high_rank: 77
#           label: "RoundPoint Mortgage Servicing Corporation"
#           sample_count: 102.0
#         }
#         buckets {
#           low_rank: 78
#           high_rank: 78
#           label: "Midwest Recovery Systems"
#           sample_count: 102.0
#         }
#         buckets {
#           low_rank: 79
#           high_rank: 79
#           label: "CL Holdings LLC"
#           sample_count: 102.0
#         }
#         buckets {
#           low_rank: 80
#           high_rank: 80
#           label: "Ad Astra Recovery Services Inc"
#           sample_count: 100.0
#         }
#         buckets {
#           low_rank: 81
#           high_rank: 81
#           label: "Servis One, Inc., Titusville, PA Branch"
#           sample_count: 98.0
#         }
#         buckets {
#           low_rank: 82
#           high_rank: 82
#           label: "Receivables Performance Management, LLC"
#           sample_count: 98.0
#         }
#         buckets {
#           low_rank: 83
#           high_rank: 83
#           label: "ProCollect, Inc."
#           sample_count: 98.0
#         }
#         buckets {
#           low_rank: 84
#           high_rank: 84
#           label: "Netspend Corporation"
#           sample_count: 95.0
#         }
#         buckets {
#           low_rank: 85
#           high_rank: 85
#           label: "TOYOTA MOTOR CREDIT CORPORATION"
#           sample_count: 91.0
#         }
#         buckets {
#           low_rank: 86
#           high_rank: 86
#           label: "CMRE Financial Services, Inc."
#           sample_count: 91.0
#         }
#         buckets {
#           low_rank: 87
#           high_rank: 87
#           label: "CAVALRY INVESTMENTS, LLC"
#           sample_count: 90.0
#         }
#         buckets {
#           low_rank: 88
#           high_rank: 88
#           label: "ACS Education Services"
#           sample_count: 90.0
#         }
#         buckets {
#           low_rank: 89
#           high_rank: 89
#           label: "The CBE Group, Inc."
#           sample_count: 88.0
#         }
#         buckets {
#           low_rank: 90
#           high_rank: 90
#           label: "GREAT LAKES"
#           sample_count: 87.0
#         }
#         buckets {
#           low_rank: 91
#           high_rank: 91
#           label: "CNG FINANCIAL CORPORATION"
#           sample_count: 87.0
#         }
#         buckets {
#           low_rank: 92
#           high_rank: 92
#           label: "NCC Business Services, Inc."
#           sample_count: 86.0
#         }
#         buckets {
#           low_rank: 93
#           high_rank: 93
#           label: "ENOVA INTERNATIONAL, INC."
#           sample_count: 86.0
#         }
#         buckets {
#           low_rank: 94
#           high_rank: 94
#           label: "Westlake Services, LLC"
#           sample_count: 85.0
#         }
#         buckets {
#           low_rank: 95
#           high_rank: 95
#           label: "I.Q. DATA INTERNATIONAL, INC."
#           sample_count: 85.0
#         }
#         buckets {
#           low_rank: 96
#           high_rank: 96
#           label: "General Motors Financial Company, Inc."
#           sample_count: 85.0
#         }
#         buckets {
#           low_rank: 97
#           high_rank: 97
#           label: "Flagstar Bank, N.A."
#           sample_count: 85.0
#         }
#         buckets {
#           low_rank: 98
#           high_rank: 98
#           label: "CURO Intermediate Holdings"
#           sample_count: 82.0
#         }
#         buckets {
#           low_rank: 99
#           high_rank: 99
#           label: "COMMUNITY CHOICE FINANCIAL, INC."
#           sample_count: 82.0
#         }
#         buckets {
#           low_rank: 100
#           high_rank: 100
#           label: "National Credit Adjusters, LLC"
#           sample_count: 80.0
#         }
#         buckets {
#           low_rank: 101
#           high_rank: 101
#           label: "IQOR US INC"
#           sample_count: 80.0
#         }
#         buckets {
#           low_rank: 102
#           high_rank: 102
#           label: "Selene Finance LP"
#           sample_count: 79.0
#         }
#         buckets {
#           low_rank: 103
#           high_rank: 103
#           label: "CREDIT ACCEPTANCE CORPORATION"
#           sample_count: 78.0
#         }
#         buckets {
#           low_rank: 104
#           high_rank: 104
#           label: "LD Holdings Group, LLC"
#           sample_count: 76.0
#         }
#         buckets {
#           low_rank: 105
#           high_rank: 105
#           label: "Financial Credit Service, Inc."
#           sample_count: 76.0
#         }
#         buckets {
#           low_rank: 106
#           high_rank: 106
#           label: "NISSAN MOTOR ACCEPTANCE COMPANY LLC"
#           sample_count: 75.0
#         }
#         buckets {
#           low_rank: 107
#           high_rank: 107
#           label: "HYUNDAI CAPITAL AMERICA"
#           sample_count: 74.0
#         }
#         buckets {
#           low_rank: 108
#           high_rank: 108
#           label: "Credit Karma, LLC"
#           sample_count: 74.0
#         }
#         buckets {
#           low_rank: 109
#           high_rank: 109
#           label: "STERLING JEWELERS, INC."
#           sample_count: 73.0
#         }
#         buckets {
#           low_rank: 110
#           high_rank: 110
#           label: "ORG GC GP Buyer, LLC"
#           sample_count: 73.0
#         }
#         buckets {
#           low_rank: 111
#           high_rank: 111
#           label: "Dynamic Recovery Solutions, LLC"
#           sample_count: 73.0
#         }
#         buckets {
#           low_rank: 112
#           high_rank: 112
#           label: "Comerica"
#           sample_count: 73.0
#         }
#         buckets {
#           low_rank: 113
#           high_rank: 113
#           label: "AMERICAN HONDA FINANCE CORP"
#           sample_count: 72.0
#         }
#         buckets {
#           low_rank: 114
#           high_rank: 114
#           label: "First National Collection Bureau, Inc."
#           sample_count: 69.0
#         }
#         buckets {
#           low_rank: 115
#           high_rank: 115
#           label: "JH Portfolio Debt Equities, LLC"
#           sample_count: 68.0
#         }
#         buckets {
#           low_rank: 116
#           high_rank: 116
#           label: "Focus Holding Company"
#           sample_count: 68.0
#         }
#         buckets {
#           low_rank: 117
#           high_rank: 117
#           label: "Credit Protection Association, L.P."
#           sample_count: 68.0
#         }
#         buckets {
#           low_rank: 118
#           high_rank: 118
#           label: "CASHCALL, INC."
#           sample_count: 68.0
#         }
#         buckets {
#           low_rank: 119
#           high_rank: 119
#           label: "Receivables Management Partners, LLC"
#           sample_count: 67.0
#         }
#         buckets {
#           low_rank: 120
#           high_rank: 120
#           label: "Genesis Lending"
#           sample_count: 67.0
#         }
#         buckets {
#           low_rank: 121
#           high_rank: 121
#           label: "Credence Resource Management, LLC"
#           sample_count: 66.0
#         }
#         buckets {
#           low_rank: 122
#           high_rank: 122
#           label: "RUSHMORE LOAN MANAGEMENT SERVICES LLC"
#           sample_count: 65.0
#         }
#         buckets {
#           low_rank: 123
#           high_rank: 123
#           label: "The CMI Group, Inc."
#           sample_count: 64.0
#         }
#         buckets {
#           low_rank: 124
#           high_rank: 124
#           label: "TCF NATIONAL BANK"
#           sample_count: 64.0
#         }
#         buckets {
#           low_rank: 125
#           high_rank: 125
#           label: "First Data Corporation"
#           sample_count: 63.0
#         }
#         buckets {
#           low_rank: 126
#           high_rank: 126
#           label: "FORD MOTOR CREDIT CO."
#           sample_count: 63.0
#         }
#         buckets {
#           low_rank: 127
#           high_rank: 127
#           label: "Amsher Collection Services, Inc."
#           sample_count: 61.0
#         }
#         buckets {
#           low_rank: 128
#           high_rank: 128
#           label: "Penn Credit Corporation"
#           sample_count: 60.0
#         }
#         buckets {
#           low_rank: 129
#           high_rank: 129
#           label: "DriveTime"
#           sample_count: 60.0
#         }
#         buckets {
#           low_rank: 130
#           high_rank: 130
#           label: "HCFS Health Care Financial Services, Inc."
#           sample_count: 59.0
#         }
#         buckets {
#           low_rank: 131
#           high_rank: 131
#           label: "FAIR COLLECTIONS & OUTSOURCING, INC."
#           sample_count: 59.0
#         }
#         buckets {
#           low_rank: 132
#           high_rank: 132
#           label: "Dovenmuehle Mortgage, Inc."
#           sample_count: 59.0
#         }
#         buckets {
#           low_rank: 133
#           high_rank: 133
#           label: "Alliance One, Inc."
#           sample_count: 59.0
#         }
#         buckets {
#           low_rank: 134
#           high_rank: 134
#           label: "Continental Finance Company, LLC"
#           sample_count: 57.0
#         }
#         buckets {
#           low_rank: 135
#           high_rank: 135
#           label: "CIT BANK, NATIONAL ASSOCIATION"
#           sample_count: 57.0
#         }
#         buckets {
#           low_rank: 136
#           high_rank: 136
#           label: "FIRST NATIONAL BANK OF OMAHA"
#           sample_count: 56.0
#         }
#         buckets {
#           low_rank: 137
#           high_rank: 137
#           label: "Risecredit, LLC"
#           sample_count: 55.0
#         }
#         buckets {
#           low_rank: 138
#           high_rank: 138
#           label: "URS Holding, LLC"
#           sample_count: 54.0
#         }
#         buckets {
#           low_rank: 139
#           high_rank: 139
#           label: "Radius Global Solutions LLC"
#           sample_count: 54.0
#         }
#         buckets {
#           low_rank: 140
#           high_rank: 140
#           label: "ECMC Group, Inc."
#           sample_count: 54.0
#         }
#         buckets {
#           low_rank: 141
#           high_rank: 141
#           label: "Debt Recovery Solutions, LLC"
#           sample_count: 54.0
#         }
#         buckets {
#           low_rank: 142
#           high_rank: 142
#           label: "Aargon Agency, Inc."
#           sample_count: 54.0
#         }
#         buckets {
#           low_rank: 143
#           high_rank: 143
#           label: "BMO HARRIS BANK NATIONAL ASSOCIATION"
#           sample_count: 53.0
#         }
#         buckets {
#           low_rank: 144
#           high_rank: 144
#           label: "Consumer Portfolio Services, Inc."
#           sample_count: 51.0
#         }
#         buckets {
#           low_rank: 145
#           high_rank: 145
#           label: "Alorica Inc."
#           sample_count: 51.0
#         }
#         buckets {
#           low_rank: 146
#           high_rank: 146
#           label: "SANTANDER BANK, NATIONAL ASSOCIATION"
#           sample_count: 50.0
#         }
#         buckets {
#           low_rank: 147
#           high_rank: 147
#           label: "Real Time Group, Inc."
#           sample_count: 50.0
#         }
#         buckets {
#           low_rank: 148
#           high_rank: 148
#           label: "Franklin Collection Service, Inc."
#           sample_count: 49.0
#         }
#         buckets {
#           low_rank: 149
#           high_rank: 149
#           label: "Fay Servicing, LLC"
#           sample_count: 49.0
#         }
#         buckets {
#           low_rank: 150
#           high_rank: 150
#           label: "BlueChip Financial"
#           sample_count: 49.0
#         }
#         buckets {
#           low_rank: 151
#           high_rank: 151
#           label: "Platinum Holdings Group, LLC"
#           sample_count: 47.0
#         }
#         buckets {
#           low_rank: 152
#           high_rank: 152
#           label: "Optimum Outcomes, Inc."
#           sample_count: 47.0
#         }
#         buckets {
#           low_rank: 153
#           high_rank: 153
#           label: "Monterey Financial Services LLC"
#           sample_count: 47.0
#         }
#         buckets {
#           low_rank: 154
#           high_rank: 154
#           label: "BANK OF THE WEST"
#           sample_count: 47.0
#         }
#         buckets {
#           low_rank: 155
#           high_rank: 155
#           label: "Advance America, Cash Advance Centers, Inc."
#           sample_count: 47.0
#         }
#         buckets {
#           low_rank: 156
#           high_rank: 156
#           label: "SQUARETWO FINANCIAL CORPORATION"
#           sample_count: 46.0
#         }
#         buckets {
#           low_rank: 157
#           high_rank: 157
#           label: "Retrieval-Masters Creditors Bureau, Inc., Elmsford, NY Branch"
#           sample_count: 46.0
#         }
#         buckets {
#           low_rank: 158
#           high_rank: 158
#           label: "Colony Brands, Inc."
#           sample_count: 46.0
#         }
#         buckets {
#           low_rank: 159
#           high_rank: 159
#           label: "CAINE & WEINER COMPANY, INC."
#           sample_count: 46.0
#         }
#         buckets {
#           low_rank: 160
#           high_rank: 160
#           label: "BMW Financial Services NA, LLC"
#           sample_count: 44.0
#         }
#         buckets {
#           low_rank: 161
#           high_rank: 161
#           label: "Weltman, Weinberg & Reis Co., L.P.A."
#           sample_count: 43.0
#         }
#         buckets {
#           low_rank: 162
#           high_rank: 162
#           label: "SECURITY FINANCE CORP"
#           sample_count: 43.0
#         }
#         buckets {
#           low_rank: 163
#           high_rank: 163
#           label: "Performant Financial Corporation"
#           sample_count: 42.0
#         }
#         buckets {
#           low_rank: 164
#           high_rank: 164
#           label: "Bliksum, LLC"
#           sample_count: 42.0
#         }
#         buckets {
#           low_rank: 165
#           high_rank: 165
#           label: "Arbor Residential Mortgage LLC"
#           sample_count: 42.0
#         }
#         buckets {
#           low_rank: 166
#           high_rank: 166
#           label: "ONLINE Information Services, Inc."
#           sample_count: 41.0
#         }
#         buckets {
#           low_rank: 167
#           high_rank: 167
#           label: "MARINER FINANCE, LLC"
#           sample_count: 41.0
#         }
#         buckets {
#           low_rank: 168
#           high_rank: 168
#           label: "Ability Recovery Services, LLC"
#           sample_count: 41.0
#         }
#         buckets {
#           low_rank: 169
#           high_rank: 169
#           label: "Residential Credit Solutions, Inc."
#           sample_count: 40.0
#         }
#         buckets {
#           low_rank: 170
#           high_rank: 170
#           label: "PENTAGON FEDERAL CREDIT UNION"
#           sample_count: 40.0
#         }
#         buckets {
#           low_rank: 171
#           high_rank: 171
#           label: "Exeter Finance Corp."
#           sample_count: 40.0
#         }
#         buckets {
#           low_rank: 172
#           high_rank: 172
#           label: "Avant Credit Corporation"
#           sample_count: 40.0
#         }
#         buckets {
#           low_rank: 173
#           high_rank: 173
#           label: "American Credit Acceptance, LLC"
#           sample_count: 40.0
#         }
#         buckets {
#           low_rank: 174
#           high_rank: 174
#           label: "Phoenix Financial Services LLC"
#           sample_count: 39.0
#         }
#         buckets {
#           low_rank: 175
#           high_rank: 175
#           label: "MUFG UNION BANK, NATIONAL ASSOCIATION"
#           sample_count: 39.0
#         }
#         buckets {
#           low_rank: 176
#           high_rank: 176
#           label: "LEXISNEXIS"
#           sample_count: 38.0
#         }
#         buckets {
#           low_rank: 177
#           high_rank: 177
#           label: "High Point Asset Inc"
#           sample_count: 38.0
#         }
#         buckets {
#           low_rank: 178
#           high_rank: 178
#           label: "Blackhawk Network Holdings Inc."
#           sample_count: 38.0
#         }
#         buckets {
#           low_rank: 179
#           high_rank: 179
#           label: "TMX Finance LLC"
#           sample_count: 37.0
#         }
#         buckets {
#           low_rank: 180
#           high_rank: 180
#           label: "Stearns Ventures, LLC"
#           sample_count: 37.0
#         }
#         buckets {
#           low_rank: 181
#           high_rank: 181
#           label: "CORELOGIC INC"
#           sample_count: 37.0
#         }
#         buckets {
#           low_rank: 182
#           high_rank: 182
#           label: "Capital Accounts, LLC"
#           sample_count: 36.0
#         }
#         buckets {
#           low_rank: 183
#           high_rank: 183
#           label: "AR Resources, Inc."
#           sample_count: 36.0
#         }
#         buckets {
#           low_rank: 184
#           high_rank: 184
#           label: "Williams & Fudge, Inc"
#           sample_count: 35.0
#         }
#         buckets {
#           low_rank: 185
#           high_rank: 185
#           label: "GOLD KEY CREDIT, INC."
#           sample_count: 35.0
#         }
#         buckets {
#           low_rank: 186
#           high_rank: 186
#           label: "First Associates Loan Servicing LLC"
#           sample_count: 35.0
#         }
#         buckets {
#           low_rank: 187
#           high_rank: 187
#           label: "CHECK INTO CASH INC."
#           sample_count: 35.0
#         }
#         buckets {
#           low_rank: 188
#           high_rank: 188
#           label: "ARVEST BANK GROUP, INC."
#           sample_count: 35.0
#         }
#         buckets {
#           low_rank: 189
#           high_rank: 189
#           label: "STATE FARM BANK, FSB"
#           sample_count: 34.0
#         }
#         buckets {
#           low_rank: 190
#           high_rank: 190
#           label: "NRA Group, LLC"
#           sample_count: 34.0
#         }
#         buckets {
#           low_rank: 191
#           high_rank: 191
#           label: "Integrated Recovery Services"
#           sample_count: 34.0
#         }
#         buckets {
#           low_rank: 192
#           high_rank: 192
#           label: "Choice Recovery, Inc."
#           sample_count: 34.0
#         }
#         buckets {
#           low_rank: 193
#           high_rank: 193
#           label: "Byrider Franchising, LLC"
#           sample_count: 34.0
#         }
#         buckets {
#           low_rank: 194
#           high_rank: 194
#           label: "Army and Air Force Exchange Service"
#           sample_count: 34.0
#         }
#         buckets {
#           low_rank: 195
#           high_rank: 195
#           label: "WAKEFIELD & ASSOCIATES, INC."
#           sample_count: 33.0
#         }
#         buckets {
#           low_rank: 196
#           high_rank: 196
#           label: "Reverse Mortgage Solutions, Inc."
#           sample_count: 33.0
#         }
#         buckets {
#           low_rank: 197
#           high_rank: 197
#           label: "Mobiloans, LLC"
#           sample_count: 33.0
#         }
#         buckets {
#           low_rank: 198
#           high_rank: 198
#           label: "Jon Barry and Associates, Inc."
#           sample_count: 33.0
#         }
#         buckets {
#           low_rank: 199
#           high_rank: 199
#           label: "Trident Asset Management, L.L.C."
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 200
#           high_rank: 200
#           label: "Synovus Bank"
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 201
#           high_rank: 201
#           label: "KBR INC DBA RASH CURTIS & ASSOCIATES"
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 202
#           high_rank: 202
#           label: "Firstsource Business Process Services, LLC"
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 203
#           high_rank: 203
#           label: "Cottonwood Financial Ltd."
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 204
#           high_rank: 204
#           label: "Capital Management Services, LP"
#           sample_count: 32.0
#         }
#         buckets {
#           low_rank: 205
#           high_rank: 205
#           label: "World Acceptance Corporation"
#           sample_count: 31.0
#         }
#         buckets {
#           low_rank: 206
#           high_rank: 206
#           label: "Medical Data Systems, Inc."
#           sample_count: 31.0
#         }
#         buckets {
#           low_rank: 207
#           high_rank: 207
#           label: "Green Square Company LLC."
#           sample_count: 31.0
#         }
#         buckets {
#           low_rank: 208
#           high_rank: 208
#           label: "TIAA, FSB"
#           sample_count: 30.0
#         }
#         buckets {
#           low_rank: 209
#           high_rank: 209
#           label: "Northland Group Inc"
#           sample_count: 30.0
#         }
#         buckets {
#           low_rank: 210
#           high_rank: 210
#           label: "National Enterprise Systems, Inc."
#           sample_count: 30.0
#         }
#         buckets {
#           low_rank: 211
#           high_rank: 211
#           label: "NCB Management Services Inc."
#           sample_count: 30.0
#         }
#         buckets {
#           low_rank: 212
#           high_rank: 212
#           label: "MOHELA"
#           sample_count: 30.0
#         }
#         buckets {
#           low_rank: 213
#           high_rank: 213
#           label: "Linebarger Goggan Blair & Sampson LLP"
#           sample_count: 30.0
#         }
#         buckets {
#           low_rank: 214
#           high_rank: 214
#           label: "AMCOL Systems, Inc."
#           sample_count: 30.0
#         }
#         buckets {
#           low_rank: 215
#           high_rank: 215
#           label: "Tower Loan of Mississippi, Inc."
#           sample_count: 29.0
#         }
#         buckets {
#           low_rank: 216
#           high_rank: 216
#           label: "Rent Recovery Solutions"
#           sample_count: 29.0
#         }
#         buckets {
#           low_rank: 217
#           high_rank: 217
#           label: "Professional Debt Mediation, Inc."
#           sample_count: 29.0
#         }
#         buckets {
#           low_rank: 218
#           high_rank: 218
#           label: "LOBEL FINANCIAL CORPORATION"
#           sample_count: 29.0
#         }
#         buckets {
#           low_rank: 219
#           high_rank: 219
#           label: "Harris & Harris, Ltd."
#           sample_count: 29.0
#         }
#         buckets {
#           low_rank: 220
#           high_rank: 220
#           label: "HEARTLAND PAYMENT SYSTEMS INC"
#           sample_count: 29.0
#         }
#         buckets {
#           low_rank: 221
#           high_rank: 221
#           label: "Diversified Adjustment Service, Inc."
#           sample_count: 29.0
#         }
#         buckets {
#           low_rank: 222
#           high_rank: 222
#           label: "VW Credit"
#           sample_count: 28.0
#         }
#         buckets {
#           low_rank: 223
#           high_rank: 223
#           label: "Pacific Union Financial, LLC"
#           sample_count: 28.0
#         }
#         buckets {
#           low_rank: 224
#           high_rank: 224
#           label: "Hillcrest Davidson & Assoc"
#           sample_count: 28.0
#         }
#         buckets {
#           low_rank: 225
#           high_rank: 225
#           label: "Halsted Financial Services, LLC."
#           sample_count: 28.0
#         }
#         buckets {
#           low_rank: 226
#           high_rank: 226
#           label: "Credit Systems International, Inc."
#           sample_count: 28.0
#         }
#         buckets {
#           low_rank: 227
#           high_rank: 227
#           label: "Capio Partners, LLC"
#           sample_count: 28.0
#         }
#         buckets {
#           low_rank: 228
#           high_rank: 228
#           label: "Adler Wallach & Associates, Inc."
#           sample_count: 28.0
#         }
#         buckets {
#           low_rank: 229
#           high_rank: 229
#           label: "Regional Management Corporation"
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 230
#           high_rank: 230
#           label: "R.M. Galicia, Inc."
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 231
#           high_rank: 231
#           label: "Professional Recovery Management"
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 232
#           high_rank: 232
#           label: "PLANET HOME LENDING, LLC"
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 233
#           high_rank: 233
#           label: "Google Compare Credit Cards Inc."
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 234
#           high_rank: 234
#           label: "Global Credit & Collection Corporation"
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 235
#           high_rank: 235
#           label: "FC HoldCo LLC"
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 236
#           high_rank: 236
#           label: "Asset Management Outsourcing, Inc."
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 237
#           high_rank: 237
#           label: "Utah System of Higher Education"
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 238
#           high_rank: 238
#           label: "United Revenue Corporation"
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 239
#           high_rank: 239
#           label: "MRS BPO, LLC"
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 240
#           high_rank: 240
#           label: "HUNTINGTON NATIONAL BANK, THE - FIRSTMERIT BANK, N.A. BRANCH"
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 241
#           high_rank: 241
#           label: "GULF COAST COLLECTION BUREAU, INC."
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 242
#           high_rank: 242
#           label: "GLA Collection Company, Inc."
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 243
#           high_rank: 243
#           label: "Financial Business and Consumer Solutions."
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 244
#           high_rank: 244
#           label: "Early Warning Services, LLC"
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 245
#           high_rank: 245
#           label: "D. SCOTT CARRUTHERS"
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 246
#           high_rank: 246
#           label: "AMERISAVE MORTGAGE CORPORATION"
#           sample_count: 26.0
#         }
#         buckets {
#           low_rank: 247
#           high_rank: 247
#           label: "State Collection Service, Inc."
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 248
#           high_rank: 248
#           label: "SUNRISE CREDIT SERVICES, INC"
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 249
#           high_rank: 249
#           label: "Ray Klein, Inc."
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 250
#           high_rank: 250
#           label: "Northstar Location Services, LLC"
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 251
#           high_rank: 251
#           label: "Nationwide Biweekly Administration, Inc."
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 252
#           high_rank: 252
#           label: "LENDER LIVE"
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 253
#           high_rank: 253
#           label: "Grant & Weber"
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 254
#           high_rank: 254
#           label: "GVA Holdings, LLC"
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 255
#           high_rank: 255
#           label: "AmeriCollect"
#           sample_count: 25.0
#         }
#         buckets {
#           low_rank: 256
#           high_rank: 256
#           label: "FIRST NATIONAL BANK OF PENNSYLVANIA"
#           sample_count: 24.0
#         }
#         buckets {
#           low_rank: 257
#           high_rank: 257
#           label: "Direct Recovery Services, LLC"
#           sample_count: 24.0
#         }
#         buckets {
#           low_rank: 258
#           high_rank: 258
#           label: "Continental Services Group, Inc. d/b/a ConServe"
#           sample_count: 24.0
#         }
#         buckets {
#           low_rank: 259
#           high_rank: 259
#           label: "Windham Professionals, Inc."
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 260
#           high_rank: 260
#           label: "Solidus Group LLC."
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 261
#           high_rank: 261
#           label: "R & B Corporation of Virginia"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 262
#           high_rank: 262
#           label: "PRESTIGE FINANCIAL SERVICES INC"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 263
#           high_rank: 263
#           label: "National Principal Group, LLC"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 264
#           high_rank: 264
#           label: "FIRST HORIZON BANK"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 265
#           high_rank: 265
#           label: "BOK FINANCIAL CORP"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 266
#           high_rank: 266
#           label: "Atlanticus Services Corporation"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 267
#           high_rank: 267
#           label: "Patenaude & Felix A Professional Corporation"
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 268
#           high_rank: 268
#           label: "Mercedes Benz Financial Services"
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 269
#           high_rank: 269
#           label: "Meade & Associates, Inc."
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 270
#           high_rank: 270
#           label: "Lending Club Corp"
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 271
#           high_rank: 271
#           label: "Delbert Services"
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 272
#           high_rank: 272
#           label: "Collection Bureau of America Ltd."
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 273
#           high_rank: 273
#           label: "Bridgecrest Acceptance Corporation"
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 274
#           high_rank: 274
#           label: "Allied Collection Services, Inc. (Nevada)"
#           sample_count: 22.0
#         }
#         buckets {
#           low_rank: 275
#           high_rank: 275
#           label: "Statebridge Company"
#           sample_count: 21.0
#         }
#         buckets {
#           low_rank: 276
#           high_rank: 276
#           label: "Seattle Service Bureau, Inc"
#           sample_count: 21.0
#         }
#         buckets {
#           low_rank: 277
#           high_rank: 277
#           label: "North Shore Agency, LLC"
#           sample_count: 21.0
#         }
#         buckets {
#           low_rank: 278
#           high_rank: 278
#           label: "FirstPoint Collection Resources"
#           sample_count: 21.0
#         }
#         buckets {
#           low_rank: 279
#           high_rank: 279
#           label: "CARDINAL FINANCIAL COMPANY"
#           sample_count: 21.0
#         }
#         buckets {
#           low_rank: 280
#           high_rank: 280
#           label: "Bull City Financial Solutions, Inc"
#           sample_count: 21.0
#         }
#         buckets {
#           low_rank: 281
#           high_rank: 281
#           label: "Atlantic Credit & Finance, Inc."
#           sample_count: 21.0
#         }
#         buckets {
#           low_rank: 282
#           high_rank: 282
#           label: "ZENCO COLLECTION, LLC"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 283
#           high_rank: 283
#           label: "UMPQUA HOLDINGS CORPORATION"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 284
#           high_rank: 284
#           label: "Social Finance, Inc."
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 285
#           high_rank: 285
#           label: "Revenue Recovery Corporation"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 286
#           high_rank: 286
#           label: "Pendrick Capital Partners Holding, LLC"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 287
#           high_rank: 287
#           label: "GreenSky, LLC"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 288
#           high_rank: 288
#           label: "FIRST ADVANTAGE CORPORATION"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 289
#           high_rank: 289
#           label: "FIDELITY CAPITAL HOLDINGS, INC"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 290
#           high_rank: 290
#           label: "Credit Central Holdings, LLC"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 291
#           high_rank: 291
#           label: "Collection Information Bureau, Inc."
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 292
#           high_rank: 292
#           label: "Alliant Capital Management LLC"
#           sample_count: 20.0
#         }
#         buckets {
#           low_rank: 293
#           high_rank: 293
#           label: "21ST MORTGAGE CORP."
#           sample_count: 20.0
#         }
#         buckets {
# ...
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 66657
#       }
#       unique: 47
#       top_values {
#         value: "nan"
#         frequency: 21208.0
#       }
#       top_values {
#         value: "Conventional fixed mortgage"
#         frequency: 5924.0
#       }
#       top_values {
#         value: "Other (i.e. phone, health club, etc.)"
#         frequency: 5113.0
#       }
#       top_values {
#         value: "Checking account"
#         frequency: 3745.0
#       }
#       top_values {
#         value: "I do not know"
#         frequency: 3426.0
#       }
#       top_values {
#         value: "Credit card"
#         frequency: 3042.0
#       }
#       top_values {
#         value: "Medical"
#         frequency: 2969.0
#       }
#       top_values {
#         value: "Non-federal student loan"
#         frequency: 2527.0
#       }
#       top_values {
#         value: "FHA mortgage"
#         frequency: 2444.0
#       }
#       top_values {
#         value: "Vehicle loan"
#         frequency: 2132.0
#       }
#       top_values {
#         value: "Federal student loan servicing"
#         frequency: 2078.0
#       }
#       top_values {
#         value: "Conventional adjustable mortgage (ARM)"
#         frequency: 2037.0
#       }
#       top_values {
#         value: "Other mortgage"
#         frequency: 1421.0
#       }
#       top_values {
#         value: "Other bank product/service"
#         frequency: 1341.0
#       }
#       top_values {
#         value: "Installment loan"
#         frequency: 1333.0
#       }
#       top_values {
#         value: "Payday loan"
#         frequency: 914.0
#       }
#       top_values {
#         value: "Home equity loan or line of credit"
#         frequency: 853.0
#       }
#       top_values {
#         value: "VA mortgage"
#         frequency: 710.0
#       }
#       top_values {
#         value: "Auto"
#         frequency: 438.0
#       }
#       top_values {
#         value: "Vehicle lease"
#         frequency: 384.0
#       }
#       avg_length: 15.097034454345703
#       rank_histogram {
#         buckets {
#           label: "nan"
#           sample_count: 21208.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "Conventional fixed mortgage"
#           sample_count: 5924.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "Other (i.e. phone, health club, etc.)"
#           sample_count: 5113.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "Checking account"
#           sample_count: 3745.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "I do not know"
#           sample_count: 3426.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "Credit card"
#           sample_count: 3042.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "Medical"
#           sample_count: 2969.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "Non-federal student loan"
#           sample_count: 2527.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "FHA mortgage"
#           sample_count: 2444.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "Vehicle loan"
#           sample_count: 2132.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "Federal student loan servicing"
#           sample_count: 2078.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "Conventional adjustable mortgage (ARM)"
#           sample_count: 2037.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "Other mortgage"
#           sample_count: 1421.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "Other bank product/service"
#           sample_count: 1341.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "Installment loan"
#           sample_count: 1333.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "Payday loan"
#           sample_count: 914.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "Home equity loan or line of credit"
#           sample_count: 853.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "VA mortgage"
#           sample_count: 710.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "Auto"
#           sample_count: 438.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "Vehicle lease"
#           sample_count: 384.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "Mortgage"
#           sample_count: 368.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "Savings account"
#           sample_count: 348.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "Domestic (US) money transfer"
#           sample_count: 332.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "General purpose card"
#           sample_count: 292.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "International money transfer"
#           sample_count: 229.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "Federal student loan"
#           sample_count: 211.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "Reverse mortgage"
#           sample_count: 157.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "(CD) Certificate of deposit"
#           sample_count: 127.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "Title loan"
#           sample_count: 84.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "Payroll card"
#           sample_count: 83.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "Cashing a check without an account"
#           sample_count: 59.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "Gift or merchant card"
#           sample_count: 50.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "ID prepaid card"
#           sample_count: 43.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "Government benefit payment card"
#           sample_count: 38.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "Debt settlement"
#           sample_count: 37.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "Mobile wallet"
#           sample_count: 31.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "Check cashing"
#           sample_count: 27.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "Other special purpose card"
#           sample_count: 23.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "Personal line of credit"
#           sample_count: 17.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "Credit repair"
#           sample_count: 15.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "Pawn loan"
#           sample_count: 12.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "Money order"
#           sample_count: 10.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "Transit card"
#           sample_count: 8.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "Refund anticipation check"
#           sample_count: 7.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "Traveler\342\200\231s/Cashier\342\200\231s checks"
#           sample_count: 5.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "Foreign currency exchange"
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "Electronic Benefit Transfer / EBT card"
#           sample_count: 1.0
#         }
#       }
#     }
#     path {
#       step: "sub_product"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 66657
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 66657
#       }
#       unique: 2
#       top_values {
#         value: "Yes"
#         frequency: 64102.0
#       }
#       top_values {
#         value: "No"
#         frequency: 2555.0
#       }
#       avg_length: 2.961669445037842
#       rank_histogram {
#         buckets {
#           label: "Yes"
#           sample_count: 64102.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "No"
#           sample_count: 2555.0
#         }
#       }
#     }
#     path {
#       step: "timely_response"
#     }
#   }
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 66657
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6665.7
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 66657
#       }
#       mean: 56050.39737761977
#       std_dev: 28958.42027064316
#       min: 11111.0
#       median: 48317.0
#       max: 99999.0
#       histograms {
#         buckets {
#           low_value: 11111.0
#           high_value: 19999.8
#           sample_count: 7074.6230837004405
#         }
#         buckets {
#           low_value: 19999.8
#           high_value: 28888.6
#           sample_count: 6345.530932920058
#         }
#         buckets {
#           low_value: 28888.6
#           high_value: 37777.399999999994
#           sample_count: 13651.505723639237
#         }
#         buckets {
#           low_value: 37777.399999999994
#           high_value: 46666.2
#           sample_count: 4804.3445150594125
#         }
#         buckets {
#           low_value: 46666.2
#           high_value: 55555.0
#           sample_count: 4830.5628587748115
#         }
#         buckets {
#           low_value: 55555.0
#           high_value: 64443.799999999996
#           sample_count: 1921.881342696163
#         }
#         buckets {
#           low_value: 64443.799999999996
#           high_value: 73332.59999999999
#           sample_count: 1537.8907159592675
#         }
#         buckets {
#           low_value: 73332.59999999999
#           high_value: 82221.4
#           sample_count: 7473.7446338507625
#         }
#         buckets {
#           low_value: 82221.4
#           high_value: 91110.2
#           sample_count: 4492.381070357341
#         }
#         buckets {
#           low_value: 91110.2
#           high_value: 99999.0
#           sample_count: 14524.53512304251
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 11111.0
#           high_value: 19434.0
#           sample_count: 6672.0
#         }
#         buckets {
#           low_value: 19434.0
#           high_value: 28752.0
#           sample_count: 6665.0
#         }
#         buckets {
#           low_value: 28752.0
#           high_value: 33325.0
#           sample_count: 6672.0
#         }
#         buckets {
#           low_value: 33325.0
#           high_value: 37228.0
#           sample_count: 6665.0
#         }
#         buckets {
#           low_value: 37228.0
#           high_value: 48317.0
#           sample_count: 6659.0
#         }
#         buckets {
#           low_value: 48317.0
#           high_value: 73112.0
#           sample_count: 6674.0
#         }
#         buckets {
#           low_value: 73112.0
#           high_value: 78723.0
#           sample_count: 6662.0
#         }
#         buckets {
#           low_value: 78723.0
#           high_value: 91764.0
#           sample_count: 6642.0
#         }
#         buckets {
#           low_value: 91764.0
#           high_value: 94568.0
#           sample_count: 6692.0
#         }
#         buckets {
#           low_value: 94568.0
#           high_value: 99999.0
#           sample_count: 6654.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "zip_code"
#     }
#   }
# }

# %% [markdown]
# ## 데이터셋 스키마(Schema)
# 의미: 데이터셋 표현을 정의한 구조.
# 구성: 피처, 각 피처의 데이터형과 데이터 범위를 정의해야 한다(스키마 객체를 생성해 살펴보면 알 수 있다).
# 용도: 데이터셋 검증 외에도 데이터 전처리 시에도 필요.
#
# [schema protobuf 정의](https://github.com/tensorflow/metadata/blob/master/tensorflow_metadata/proto/v0/schema.proto)

# %%
schema = tfdv.infer_schema(stats)

# %%
schema
# Out:
# feature {
#   name: "company"
#   type: BYTES
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "company_response"
#   type: BYTES
#   domain: "company_response"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "consumer_disputed"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "issue"
#   type: BYTES
#   domain: "issue"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "product"
#   type: BYTES
#   domain: "product"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "state"
#   type: BYTES
#   domain: "state"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "sub_issue"
#   type: BYTES
#   domain: "sub_issue"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "sub_product"
#   type: BYTES
#   domain: "sub_product"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "timely_response"
#   type: BYTES
#   domain: "timely_response"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "zip_code"
#   type: INT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# string_domain {
#   name: "company_response"
#   value: "Company believes complaint caused principally by actions of third party outside the control or direction of the company"
#   value: "Company believes complaint is the result of an isolated error"
#   value: "Company believes complaint relates to a discontinued policy or procedure"
#   value: "Company believes complaint represents an opportunity for improvement to better serve consumers"
#   value: "Company believes it acted appropriately as authorized by contract or law"
#   value: "Company believes the complaint is the result of a misunderstanding"
#   value: "Company can\'t verify or dispute the facts in the complaint"
#   value: "Company chooses not to provide a public response"
#   value: "Company disputes the facts presented in the complaint"
#   value: "Company has responded to the consumer and the CFPB and chooses not to provide a public response"
#   value: "nan"
# }
# string_domain {
#   name: "issue"
#   value: "APR or interest rate"
#   value: "Account opening, closing, or management"
#   value: "Account terms and changes"
#   value: "Adding money"
#   value: "Advertising and marketing"
#   value: "Advertising, marketing or disclosures"
#   value: "Application processing delay"
#   value: "Application, originator, mortgage broker"
#   value: "Applied for loan/did not receive money"
#   value: "Arbitration"
#   value: "Balance transfer"
#   value: "Balance transfer fee"
#   value: "Bankruptcy"
#   value: "Billing disputes"
#   value: "Billing statement"
#   value: "Can\'t contact lender"
#   value: "Can\'t repay my loan"
#   value: "Can\'t stop charges to bank account"
#   value: "Cash advance"
#   value: "Cash advance fee"
#   value: "Charged bank acct wrong day or amt"
#   value: "Charged fees or interest I didn\'t expect"
#   value: "Closing/Cancelling account"
#   value: "Communication tactics"
#   value: "Cont\'d attempts collect debt not owed"
#   value: "Convenience checks"
#   value: "Credit card protection / Debt protection"
#   value: "Credit decision / Underwriting"
#   value: "Credit determination"
#   value: "Credit line increase/decrease"
#   value: "Credit monitoring or identity protection"
#   value: "Credit reporting company\'s investigation"
#   value: "Customer service / Customer relations"
#   value: "Customer service/Customer relations"
#   value: "Dealing with my lender or servicer"
#   value: "Delinquent account"
#   value: "Deposits and withdrawals"
#   value: "Disclosure verification of debt"
#   value: "Disclosures"
#   value: "Excessive fees"
#   value: "False statements or representation"
#   value: "Fees"
#   value: "Forbearance / Workout plans"
#   value: "Fraud or scam"
#   value: "Getting a loan"
#   value: "Identity theft / Fraud / Embezzlement"
#   value: "Improper contact or sharing of info"
#   value: "Improper use of my credit report"
#   value: "Incorrect exchange rate"
#   value: "Incorrect information on credit report"
#   value: "Incorrect/missing disclosures or info"
#   value: "Late fee"
#   value: "Lender damaged or destroyed vehicle"
#   value: "Lender repossessed or sold the vehicle"
#   value: "Lender sold the property"
#   value: "Loan modification,collection,foreclosure"
#   value: "Loan servicing, payments, escrow account"
#   value: "Lost or stolen check"
#   value: "Lost or stolen money order"
#   value: "Making/receiving payments, sending money"
#   value: "Managing the line of credit"
#   value: "Managing the loan or lease"
#   value: "Managing, opening, or closing account"
#   value: "Money was not available when promised"
#   value: "Other"
#   value: "Other fee"
#   value: "Other service issues"
#   value: "Other transaction issues"
#   value: "Overdraft, savings or rewards features"
#   value: "Overlimit fee"
#   value: "Payment to acct not credited"
#   value: "Payoff process"
#   value: "Privacy"
#   value: "Problems caused by my funds being low"
#   value: "Problems when you are unable to pay"
#   value: "Received a loan I didn\'t apply for"
#   value: "Rewards"
#   value: "Sale of account"
#   value: "Settlement process and costs"
#   value: "Shopping for a line of credit"
#   value: "Shopping for a loan or lease"
#   value: "Taking out the loan or lease"
#   value: "Taking/threatening an illegal action"
#   value: "Transaction issue"
#   value: "Unable to get credit report/credit score"
#   value: "Unauthorized transactions/trans. issues"
#   value: "Unexpected/Other fees"
#   value: "Unsolicited issuance of credit card"
#   value: "Using a debit or ATM card"
#   value: "Wrong amount charged or received"
# }
# string_domain {
#   name: "product"
#   value: "Bank account or service"
#   value: "Consumer Loan"
#   value: "Credit card"
#   value: "Credit reporting"
#   value: "Debt collection"
#   value: "Money transfers"
#   value: "Mortgage"
#   value: "Other financial service"
#   value: "Payday loan"
#   value: "Prepaid card"
#   value: "Student loan"
#   value: "Virtual currency"
# }
# string_domain {
#   name: "state"
#   value: "AA"
#   value: "AE"
#   value: "AK"
#   value: "AL"
#   value: "AP"
#   value: "AR"
#   value: "AS"
#   value: "AZ"
#   value: "CA"
#   value: "CO"
#   value: "CT"
#   value: "DC"
#   value: "DE"
#   value: "FL"
#   value: "FM"
#   value: "GA"
#   value: "GU"
#   value: "HI"
#   value: "IA"
#   value: "ID"
#   value: "IL"
#   value: "IN"
#   value: "KS"
#   value: "KY"
#   value: "LA"
#   value: "MA"
#   value: "MD"
#   value: "ME"
#   value: "MH"
#   value: "MI"
#   value: "MN"
#   value: "MO"
#   value: "MP"
#   value: "MS"
#   value: "MT"
#   value: "NC"
#   value: "ND"
#   value: "NE"
#   value: "NJ"
#   value: "NM"
#   value: "NV"
#   value: "NY"
#   value: "OH"
#   value: "OK"
#   value: "OR"
#   value: "PA"
#   value: "PR"
#   value: "RI"
#   value: "SC"
#   value: "SD"
#   value: "TN"
#   value: "TX"
#   value: "UT"
#   value: "VA"
#   value: "VI"
#   value: "VT"
#   value: "WA"
#   value: "WI"
#   value: "WV"
#   value: "WY"
#   value: "nan"
# }
# string_domain {
#   name: "sub_issue"
#   value: "Account status"
#   value: "Account terms"
#   value: "Account terms and changes"
#   value: "Attempted to collect wrong amount"
#   value: "Attempted to/Collected exempt funds"
#   value: "Billing dispute"
#   value: "Called after sent written cease of comm"
#   value: "Called outside of 8am-9pm"
#   value: "Can\'t decrease my monthly payments"
#   value: "Can\'t get flexible payment options"
#   value: "Can\'t qualify for a loan"
#   value: "Can\'t temporarily postpone payments"
#   value: "Contacted employer after asked not to"
#   value: "Contacted me after I asked not to"
#   value: "Contacted me instead of my attorney"
#   value: "Debt is not mine"
#   value: "Debt resulted from identity theft"
#   value: "Debt was discharged in bankruptcy"
#   value: "Debt was paid"
#   value: "Don\'t agree with fees charged"
#   value: "Frequent or repeated calls"
#   value: "Having problems with customer service"
#   value: "Impersonated an attorney or official"
#   value: "Inadequate help over the phone"
#   value: "Indicated committed crime not paying"
#   value: "Indicated shouldn\'t respond to lawsuit"
#   value: "Information is not mine"
#   value: "Investigation took too long"
#   value: "Keep getting calls about my loan"
#   value: "Need information about my balance/terms"
#   value: "No notice of investigation status/result"
#   value: "Not disclosed as an attempt to collect"
#   value: "Not given enough info to verify debt"
#   value: "Personal information"
#   value: "Problem cancelling or closing account"
#   value: "Problem getting my free annual report"
#   value: "Problem getting report or credit score"
#   value: "Problem with fraud alerts"
#   value: "Problem with statement of dispute"
#   value: "Public record"
#   value: "Qualify for a better loan than offered"
#   value: "Received bad information about my loan"
#   value: "Received marketing offer after opted out"
#   value: "Receiving unwanted marketing/advertising"
#   value: "Reinserted previously deleted info"
#   value: "Report improperly shared by CRC"
#   value: "Report shared with employer w/o consent"
#   value: "Right to dispute notice not received"
#   value: "Seized/Attempted to seize property"
#   value: "Sued w/o proper notification of suit"
#   value: "Sued where didn\'t live/sign for debt"
#   value: "Talked to a third party about my debt"
#   value: "Threatened arrest/jail if do not pay"
#   value: "Threatened to sue on too old debt"
#   value: "Threatened to take legal action"
#   value: "Trouble with how payments are handled"
#   value: "Used obscene/profane/abusive language"
#   value: "nan"
# }
# string_domain {
#   name: "sub_product"
#   value: "(CD) Certificate of deposit"
#   value: "Auto"
#   value: "Cashing a check without an account"
#   value: "Check cashing"
#   value: "Checking account"
#   value: "Conventional adjustable mortgage (ARM)"
#   value: "Conventional fixed mortgage"
#   value: "Credit card"
#   value: "Credit repair"
#   value: "Debt settlement"
#   value: "Domestic (US) money transfer"
#   value: "Electronic Benefit Transfer / EBT card"
#   value: "FHA mortgage"
#   value: "Federal student loan"
#   value: "Federal student loan servicing"
#   value: "Foreign currency exchange"
#   value: "General purpose card"
#   value: "Gift or merchant card"
#   value: "Government benefit payment card"
#   value: "Home equity loan or line of credit"
#   value: "I do not know"
#   value: "ID prepaid card"
#   value: "Installment loan"
#   value: "International money transfer"
#   value: "Medical"
#   value: "Mobile wallet"
#   value: "Money order"
#   value: "Mortgage"
#   value: "Non-federal student loan"
#   value: "Other (i.e. phone, health club, etc.)"
#   value: "Other bank product/service"
#   value: "Other mortgage"
#   value: "Other special purpose card"
#   value: "Pawn loan"
#   value: "Payday loan"
#   value: "Payroll card"
#   value: "Personal line of credit"
#   value: "Refund anticipation check"
#   value: "Reverse mortgage"
#   value: "Savings account"
#   value: "Title loan"
#   value: "Transit card"
#   value: "Traveler\342\200\231s/Cashier\342\200\231s checks"
#   value: "VA mortgage"
#   value: "Vehicle lease"
#   value: "Vehicle loan"
#   value: "nan"
# }
# string_domain {
#   name: "timely_response"
#   value: "No"
#   value: "Yes"
# }

# %%
tfdv.display_schema(schema)  # facets를 백엔드로 사용한 시각화.
# Presence: 필수인가 아닌가. NaN 허용 여부. 이는 데이터 사용자에 의한 필수 여부가 아니라,
#       TFDV에서 추론한 것이다.
# Valency: 하나의 학습 예제에서 피처의 값이 몇 개여야 하는지 정한다.
#       categorical feature가 single이면 단일 범주를 지녀야 한다(cat이면서 dog일 순 없다).
#       valency=3이라면 example의 그 피처가 [1, 2, 3] 같은 형태라는 뜻이다.
# Out:
#                        Type  Presence Valency              Domain
# Feature name
# 'company'             BYTES  required                           -
# 'company_response'   STRING  required          'company_response'
# 'consumer_disputed'   FLOAT  required                           -
# 'issue'              STRING  required                     'issue'
# 'product'            STRING  required                   'product'
# 'state'              STRING  required                     'state'
# 'sub_issue'          STRING  required                 'sub_issue'
# 'sub_product'        STRING  required               'sub_product'
# 'timely_response'    STRING  required           'timely_response'
# 'zip_code'              INT  required                           -
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Values
# Domain
# 'company_response'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'Company believes complaint caused principally by actions of third party outside the control or direction of the company', 'Company believes complaint is the result of an isolated error', 'Company believes complaint relates to a discontinued policy or procedure', 'Company believes complaint represents an opportunity for improvement to better serve consumers', 'Company believes it acted appropriately as authorized by contract or law', 'Company believes the complaint is the result of a misunderstanding', 'Company can\'t verify or dispute the facts in the complaint', 'Company chooses not to provide a public response', 'Company disputes the facts presented in the complaint', 'Company has responded to the consumer and the CFPB and chooses not to provide a public response', 'nan'
# 'issue'             'APR or interest rate', 'Account opening, closing, or management', 'Account terms and changes', 'Adding money', 'Advertising and marketing', 'Advertising, marketing or disclosures', 'Application processing delay', 'Application, originator, mortgage broker', 'Applied for loan/did not receive money', 'Arbitration', 'Balance transfer', 'Balance transfer fee', 'Bankruptcy', 'Billing disputes', 'Billing statement', 'Can\'t contact lender', 'Can\'t repay my loan', 'Can\'t stop charges to bank account', 'Cash advance', 'Cash advance fee', 'Charged bank acct wrong day or amt', 'Charged fees or interest I didn\'t expect', 'Closing/Cancelling account', 'Communication tactics', 'Cont\'d attempts collect debt not owed', 'Convenience checks', 'Credit card protection / Debt protection', 'Credit decision / Underwriting', 'Credit determination', 'Credit line increase/decrease', 'Credit monitoring or identity protection', 'Credit reporting company\'s investigation', 'Customer service / Customer relations', 'Customer service/Customer relations', 'Dealing with my lender or servicer', 'Delinquent account', 'Deposits and withdrawals', 'Disclosure verification of debt', 'Disclosures', 'Excessive fees', 'False statements or representation', 'Fees', 'Forbearance / Workout plans', 'Fraud or scam', 'Getting a loan', 'Identity theft / Fraud / Embezzlement', 'Improper contact or sharing of info', 'Improper use of my credit report', 'Incorrect exchange rate', 'Incorrect information on credit report', 'Incorrect/missing disclosures or info', 'Late fee', 'Lender damaged or destroyed vehicle', 'Lender repossessed or sold the vehicle', 'Lender sold the property', 'Loan modification,collection,foreclosure', 'Loan servicing, payments, escrow account', 'Lost or stolen check', 'Lost or stolen money order', 'Making/receiving payments, sending money', 'Managing the line of credit', 'Managing the loan or lease', 'Managing, opening, or closing account', 'Money was not available when promised', 'Other', 'Other fee', 'Other service issues', 'Other transaction issues', 'Overdraft, savings or rewards features', 'Overlimit fee', 'Payment to acct not credited', 'Payoff process', 'Privacy', 'Problems caused by my funds being low', 'Problems when you are unable to pay', 'Received a loan I didn\'t apply for', 'Rewards', 'Sale of account', 'Settlement process and costs', 'Shopping for a line of credit', 'Shopping for a loan or lease', 'Taking out the loan or lease', 'Taking/threatening an illegal action', 'Transaction issue', 'Unable to get credit report/credit score', 'Unauthorized transactions/trans. issues', 'Unexpected/Other fees', 'Unsolicited issuance of credit card', 'Using a debit or ATM card', 'Wrong amount charged or received'
# 'product'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'Bank account or service', 'Consumer Loan', 'Credit card', 'Credit reporting', 'Debt collection', 'Money transfers', 'Mortgage', 'Other financial service', 'Payday loan', 'Prepaid card', 'Student loan', 'Virtual currency'
# 'state'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'AA', 'AE', 'AK', 'AL', 'AP', 'AR', 'AS', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'FM', 'GA', 'GU', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MH', 'MI', 'MN', 'MO', 'MP', 'MS', 'MT', 'NC', 'ND', 'NE', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VI', 'VT', 'WA', 'WI', 'WV', 'WY', 'nan'
# 'sub_issue'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'Account status', 'Account terms', 'Account terms and changes', 'Attempted to collect wrong amount', 'Attempted to/Collected exempt funds', 'Billing dispute', 'Called after sent written cease of comm', 'Called outside of 8am-9pm', 'Can\'t decrease my monthly payments', 'Can\'t get flexible payment options', 'Can\'t qualify for a loan', 'Can\'t temporarily postpone payments', 'Contacted employer after asked not to', 'Contacted me after I asked not to', 'Contacted me instead of my attorney', 'Debt is not mine', 'Debt resulted from identity theft', 'Debt was discharged in bankruptcy', 'Debt was paid', 'Don\'t agree with fees charged', 'Frequent or repeated calls', 'Having problems with customer service', 'Impersonated an attorney or official', 'Inadequate help over the phone', 'Indicated committed crime not paying', 'Indicated shouldn\'t respond to lawsuit', 'Information is not mine', 'Investigation took too long', 'Keep getting calls about my loan', 'Need information about my balance/terms', 'No notice of investigation status/result', 'Not disclosed as an attempt to collect', 'Not given enough info to verify debt', 'Personal information', 'Problem cancelling or closing account', 'Problem getting my free annual report', 'Problem getting report or credit score', 'Problem with fraud alerts', 'Problem with statement of dispute', 'Public record', 'Qualify for a better loan than offered', 'Received bad information about my loan', 'Received marketing offer after opted out', 'Receiving unwanted marketing/advertising', 'Reinserted previously deleted info', 'Report improperly shared by CRC', 'Report shared with employer w/o consent', 'Right to dispute notice not received', 'Seized/Attempted to seize property', 'Sued w/o proper notification of suit', 'Sued where didn\'t live/sign for debt', 'Talked to a third party about my debt', 'Threatened arrest/jail if do not pay', 'Threatened to sue on too old debt', 'Threatened to take legal action', 'Trouble with how payments are handled', 'Used obscene/profane/abusive language', 'nan'
# 'sub_product'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              '(CD) Certificate of deposit', 'Auto', 'Cashing a check without an account', 'Check cashing', 'Checking account', 'Conventional adjustable mortgage (ARM)', 'Conventional fixed mortgage', 'Credit card', 'Credit repair', 'Debt settlement', 'Domestic (US) money transfer', 'Electronic Benefit Transfer / EBT card', 'FHA mortgage', 'Federal student loan', 'Federal student loan servicing', 'Foreign currency exchange', 'General purpose card', 'Gift or merchant card', 'Government benefit payment card', 'Home equity loan or line of credit', 'I do not know', 'ID prepaid card', 'Installment loan', 'International money transfer', 'Medical', 'Mobile wallet', 'Money order', 'Mortgage', 'Non-federal student loan', 'Other (i.e. phone, health club, etc.)', 'Other bank product/service', 'Other mortgage', 'Other special purpose card', 'Pawn loan', 'Payday loan', 'Payroll card', 'Personal line of credit', 'Refund anticipation check', 'Reverse mortgage', 'Savings account', 'Title loan', 'Transit card', 'Traveler’s/Cashier’s checks', 'VA mortgage', 'Vehicle lease', 'Vehicle loan', 'nan'
# 'timely_response'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'No', 'Yes'

# %% [markdown]
# ### 스키마로 두 데이터셋 간 비교

# %%
record_dir = os.path.join(data_dir, 'complaints', 'splits')
train_record_path = os.path.join(record_dir, 'train', 'train.tfrecord')
eval_record_path = os.path.join(record_dir, 'eval', 'eval.tfrecord')

train_stats = tfdv.generate_statistics_from_tfrecord(data_location=train_record_path)
eval_stats = tfdv.generate_statistics_from_tfrecord(data_location=eval_record_path)
# Out:
# WARNING:apache_beam.io.tfrecordio:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# WARNING:tensorflow:From /home/hakjun/projects/pipeline/venv/lib/python3.8/site-packages/tensorflow_data_validation/utils/statistics_io_impl.py:91: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /home/hakjun/projects/pipeline/venv/lib/python3.8/site-packages/tensorflow_data_validation/utils/statistics_io_impl.py:91: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
# lhs: left-hand side, rhs: right-hand side
# 데이터셋에 이상이 있다고 판단하면 그 부분을 강조 표시한다.
tfdv.visualize_statistics(lhs_statistics=train_stats, lhs_name='Trainset',
                          rhs_statistics=eval_stats, rhs_name='Validset')
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
# 데이터셋에서 생성한 통계에 이상치가 있는지 스키마를 기준으로 검사한다.
anomalies = tfdv.validate_statistics(statistics=eval_stats, schema=schema)

# %%
tfdv.display_anomalies(anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %%
# 스키마를 직렬화시켜 파일로 저장할 수도 있다.
tfdv.write_schema_text(schema, "metadata/complaints_schem")

# %%
# 스키마 업데이트: 피처의 설정값들을 조정 가능.
sub_issue_feat = tfdv.get_feature(schema, "sub_issue")
# example들의 90% 이상에 존재해야 한다는 제약 설정.
sub_issue_feat.presence.min_fraction = 0.9

# %%
# '도메인'이란 피처의 값 공간 - 데이터셋에서 이 피처가 어떤 값들을 지니고 있는지 - 를 나열한다.
state_domain = tfdv.get_domain(schema, "state")
# 특정 값을 도메인에서 제거
state_domain.value.remove("AK")

# %%
# 'state' 열에서 알래스카("AK") 값은 허용되지 않도록 스키마를 업데이트 했기에,
# 현재 eval 데이터셋에 그 내용의 이상치가 감지됐다.
updated_anomalies = tfdv.validate_statistics(eval_stats, schema=schema)
tfdv.display_anomalies(updated_anomalies)
# Out:
#              Anomaly short description  \
# Feature name
# 'state'       Unexpected string values
#
#                                                  Anomaly long description
# Feature name
# 'state'       Examples contain values missing from the schema: AK (<1%).

# %% [markdown]
# ### Data skew & drift
# 데이터 스큐: 두 데이터셋 간 통계 분포의 큰 차이를 감지. 이는 통계학에서의 skew의 정의(평균에서 떨어진
# 정도)와 다르다. TFDV의 내장 스큐 비교기는 두 데이터셋 간 `service_statistics` 차이에 대한
# L-infinity norm을 산출한다. 스큐의 임계값 초과 여부는 TFDV가 이상치 검사로 다루는 한 종류이다.
#
# L-infinity norm: 두 벡터 간 차이를 정의.
# ```Python
# v1, v2 = [5, 7, -1], [3, -5, 13]
# diff = v1 - v2  # [2, 12, -14]
# l_inifinity_norm = max(np.abs(diff))  # 14
# ```
#
# 스큐 비교기에서 두 벡터는 두 데이터셋의 요약 통계이다.

# %%
company_feat = tfdv.get_feature(schema, 'company')

# %%
# 설정된 임계값 0.01을 초과하면 이상치로 감지하도록 설정.
company_feat.skew_comparator.infinity_norm.threshold = 0.01
skew_anomalies = tfdv.validate_statistics(
    statistics=train_stats,
    schema=schema,
    serving_statistics=eval_stats)  # skew anomaly 검출을 위해 필요한 인자.

# %%
skew_anomalies.anomaly_info
# Out:
# {'state': description: "Examples contain values missing from the schema: AK (<1%). "
# severity: ERROR
# short_description: "Unexpected string values"
# reason {
#   type: ENUM_TYPE_UNEXPECTED_STRING_VALUES
#   short_description: "Unexpected string values"
#   description: "Examples contain values missing from the schema: AK (<1%). "
# }
# path {
#   step: "state"
# }
# }

# %% [markdown]
# #### Data drift

# %%
span_dir = os.path.join(data_dir, "span")
span_files = [os.path.join(span_dir, f"export-{i}", f"ver{i}.csv") for i
              in range(1, len(os.listdir(span_dir)) + 1)]

span_stats = [tfdv.generate_statistics_from_csv(file) for file in span_files]
span_schema = tfdv.infer_schema(span_stats[2])

# %%
span_schema.feature
# Out:
# [name: "LatD"
# type: INT
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# , name: " \"LatM\""
# type: INT
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# , name: " \"LatS\""
# type: INT
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# , name: " \"NS\""
# type: BYTES
# domain: " \"NS\""
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# , name: " \"LonD\""
# type: INT
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# , name: " \"LonM\""
# type: INT
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# , name: " \"LonS\""
# type: INT
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# , name: " \"EW\""
# type: BYTES
# domain: " \"EW\""
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# , name: " \"City\""
# type: BYTES
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# , name: " \"State\""
# type: BYTES
# domain: " \"State\""
# presence {
#   min_fraction: 1.0
#   min_count: 1
# }
# shape {
#   dim {
#     size: 1
#   }
# }
# ]

# %%
# 드리프트 발생 여부를 "LatD" 피처를 대상으로 검사한다.
lat_d_feat = tfdv.get_feature(schema, "LatD")
lat_d_feat.drift_comparator.infinity_norm.threshold = 0.01
drift_anomalies = tfdv.validate_statistics(
    statistics=span_stats[2],  # ver3 데이터셋이
    schema=span_schema,
    previous_statistics=span_stats[1]  # ver1과 비교해서 drift가 일어났나 확인.
)

# %% [markdown]
# ### 이외 살펴볼 문제: 편향(bias)
# 편향: 데이터가 현실을 제대로 반영하지 못하는 문제
# 선택 편향: 편향된 표본을 선택
#
# 참조: [구글 머신러닝 개발자 과정](https://developers.google.com/machine-learning/crash-course/fairness/types-of-bias)

# %% [markdown]
# ### Slicing
# SQL에서 각 행을 `GROUP BY species = "mammal"` 이런 식으로 묶을 수 있듯이,
# slicer 함수를 정의하여 각 example들도 슬라이싱별로 묶을 수 있다.

# %%
slice_by_california_fn = slicing_util.get_feature_value_slicer(
    features={"state": [b"CA"]}  # 키 피처의 값은 binary list로 제공해야 한다.
)

slice_options = tfdv.StatsOptions(slice_functions=[slice_by_california_fn])
slice_stats = tfdv.generate_statistics_from_tfrecord(
    data_location=raw_path,
    stats_options=slice_options
)

# %%
def get_slice_keys(stats):
    return list(map(lambda x: x.name, slice_stats.datasets))


def display_slice_keys(stats):
    print(get_sliced_stats(stats))


def get_sliced_stats(stats, slice_key):
    """

    :param stats: 슬라이스 된 통계 객체임을 가정한다.
    :param slice_key: `stats.datasets`의 이름 중 하나.
    :return: `slice_key`에 의해 반환된 특정 슬라이스 통계.
    """
    sliced_stats = list(filter(lambda ds: ds.name == slice_key,
                               stats.datasets))[0]

    result = stats_pb2.DatasetFeatureStatisticsList()
    result.datasets.add().CopyFrom(sliced_stats)
    return result


def compare_slices(stats, slice_key1, slice_key2):
    lhs_stats = get_sliced_stats(stats, slice_key1)
    rhs_stats = get_sliced_stats(stats, slice_key2)
    tfdv.visualize_statistics(lhs_statistics=lhs_stats, rhs_statistics=rhs_stats)

# %%
ca_stats = get_sliced_stats(slice_stats, "state_CA")

# %%
compare_slices(slice_stats, *get_slice_keys(slice_stats))
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ## 파이프라인 일부로서 TFDV
# 지금까지는 TFDV 라이브러리를 사용하여 독립실행형 데이터 검증을 실시했다. 이제 이 과정을 TFX 컴포넌트로서
# 파이프라인을 구축한다. 데이터가 통과하는 컴포넌트 순서는 다음과 같다. 각 컴포넌트는 대화형 컨텍스트
# 객체가 관리하며 완전한 파이프라인은 각 컨텍스트를 오케스트레이션 도구로 자동 관리한다.
# 1. ExampleGen
# 2. StatisticsGen
# 3. SchemaGen
# 4. ExampleValidator

# %%
context = InteractiveContext()
# Out:
# WARNING:absl:InteractiveContext pipeline_root argument not provided: using temporary directory /tmp/tfx-interactive-2023-01-11T06_57_02.948885-ch4kwyky as root for pipeline outputs.
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at /tmp/tfx-interactive-2023-01-11T06_57_02.948885-ch4kwyky/metadata.sqlite.

# %%
# 먼저 소스(이 경우 tfrecord)에서 데이터 수집을 해야 한다.
example_gen = ImportExampleGen(
    input_base=os.path.join(complaints_dir, "records"))
context.run(example_gen)
context.show(example_gen)
# Out:
# ImportExampleGen(spec: <tfx.types.standard_component_specs.FileBasedExampleGenSpec object at 0x7ff5482b8df0>, executor_spec: <tfx.dsl.components.base.executor_spec.BeamExecutorSpec object at 0x7ff5482b8f10>, driver_class: <class 'tfx.components.example_gen.driver.FileBasedDriver'>, component_id: ImportExampleGen, inputs: {}, outputs: {'examples': OutputChannel(artifact_type=Examples, producer_component_id=ImportExampleGen, output_key=examples, additional_properties={}, additional_custom_properties={})})

# %%
example_artifact = example_gen.outputs["examples"]

# %%
# 다음으로 검증을 위한 통계를 만든다.
statistics_gen = StatisticsGen(examples=example_artifact)
context.run(statistics_gen)
context.show(statistics_gen)  # 통계 내용을 보여 주는 것이 아닌, 객체 자체 정보를 보여준다.
# Out:
# StatisticsGen(spec: <tfx.types.standard_component_specs.StatisticsGenSpec object at 0x7ff54812ea60>, executor_spec: <tfx.dsl.components.base.executor_spec.BeamExecutorSpec object at 0x7ff54812e5e0>, driver_class: <class 'tfx.dsl.components.base.base_driver.BaseDriver'>, component_id: StatisticsGen, inputs: {'examples': OutputChannel(artifact_type=Examples, producer_component_id=ImportExampleGen, output_key=examples, additional_properties={}, additional_custom_properties={})}, outputs: {'statistics': OutputChannel(artifact_type=ExampleStatistics, producer_component_id=StatisticsGen, output_key=statistics, additional_properties={}, additional_custom_properties={})})

# %%
# 통계는 컴포넌트의 실행자(executor)가 생성한 아티팩트이므로 `outputs` 속성으로 검사해야 한다.
statistics_artifact = statistics_gen.outputs["statistics"]
context.show(statistics_artifact)
# Out:
# <b>Artifact at /tmp/tfx-interactive-2023-01-11T06_57_02.948885-ch4kwyky/StatisticsGen/statistics/3</b><br/><br/>
# <style>html[theme=dark] iframe {background: white;}</style>
# <div><b>'train' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <div><b>'eval' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
# 스키마는 데이터 검증과, 데이터 전처리를 모델 그래프 일부로 합체시키는 데도 필요하다.
# 파이프라인에서 스키마가 없을 시에만 이 컴포넌트가 새 스키마를 생성한다.
# 필요 시 스키마 생성 직후에 스키마를 조정하면 파이프라인 전 과정에서 사용할 수 있다.
schema_gen = SchemaGen(statistics=statistics_artifact, infer_feature_shape=True)
context.run(schema_gen)
context.show(schema_gen)
# Out:
# SchemaGen(spec: <tfx.types.standard_component_specs.SchemaGenSpec object at 0x7ff55cc5b6a0>, executor_spec: <tfx.dsl.components.base.executor_spec.ExecutorClassSpec object at 0x7ff55cc5bd00>, driver_class: <class 'tfx.dsl.components.base.base_driver.BaseDriver'>, component_id: SchemaGen, inputs: {'statistics': OutputChannel(artifact_type=ExampleStatistics, producer_component_id=StatisticsGen, output_key=statistics, additional_properties={}, additional_custom_properties={})}, outputs: {'schema': OutputChannel(artifact_type=Schema, producer_component_id=SchemaGen, output_key=schema, additional_properties={}, additional_custom_properties={})})

# %%
schema_artifact = schema_gen.outputs["schema"]
context.show(schema_artifact)
# Out:
# <b>Artifact at /tmp/tfx-interactive-2023-01-11T06_57_02.948885-ch4kwyky/SchemaGen/schema/4</b><br/><br/>
#                        Type  Presence Valency              Domain
# Feature name
# 'company'             BYTES  required                           -
# 'company_response'   STRING  required          'company_response'
# 'consumer_disputed'   FLOAT  required                           -
# 'issue'              STRING  required                     'issue'
# 'product'            STRING  required                   'product'
# 'state'              STRING  required                     'state'
# 'sub_issue'          STRING  required                 'sub_issue'
# 'sub_product'        STRING  required               'sub_product'
# 'timely_response'    STRING  required           'timely_response'
# 'zip_code'              INT  required                           -
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Values
# Domain
# 'company_response'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 'Company believes complaint caused principally by actions of third party outside the control or direction of the company', 'Company believes complaint is the result of an isolated error', 'Company believes complaint relates to a discontinued policy or procedure', 'Company believes complaint represents an opportunity for improvement to better serve consumers', 'Company believes it acted appropriately as authorized by contract or law', 'Company believes the complaint is the result of a misunderstanding', 'Company can\'t verify or dispute the facts in the complaint', 'Company chooses not to provide a public response', 'Company disputes the facts presented in the complaint', 'Company has responded to the consumer and the CFPB and chooses not to provide a public response', 'nan'
# 'issue'             'APR or interest rate', 'Account opening, closing, or management', 'Account terms and changes', 'Adding money', 'Advertising and marketing', 'Advertising, marketing or disclosures', 'Application processing delay', 'Application, originator, mortgage broker', 'Applied for loan/did not receive money', 'Arbitration', 'Balance transfer', 'Balance transfer fee', 'Bankruptcy', 'Billing disputes', 'Billing statement', 'Can\'t contact lender', 'Can\'t repay my loan', 'Can\'t stop charges to bank account', 'Cash advance', 'Cash advance fee', 'Charged bank acct wrong day or amt', 'Charged fees or interest I didn\'t expect', 'Closing/Cancelling account', 'Communication tactics', 'Cont\'d attempts collect debt not owed', 'Convenience checks', 'Credit card protection / Debt protection', 'Credit decision / Underwriting', 'Credit determination', 'Credit line increase/decrease', 'Credit monitoring or identity protection', 'Credit reporting company\'s investigation', 'Customer service / Customer relations', 'Customer service/Customer relations', 'Dealing with my lender or servicer', 'Delinquent account', 'Deposits and withdrawals', 'Disclosure verification of debt', 'Disclosures', 'Excessive fees', 'False statements or representation', 'Fees', 'Forbearance / Workout plans', 'Fraud or scam', 'Getting a loan', 'Identity theft / Fraud / Embezzlement', 'Improper contact or sharing of info', 'Improper use of my credit report', 'Incorrect exchange rate', 'Incorrect information on credit report', 'Incorrect/missing disclosures or info', 'Late fee', 'Lender repossessed or sold the vehicle', 'Lender sold the property', 'Loan modification,collection,foreclosure', 'Loan servicing, payments, escrow account', 'Lost or stolen check', 'Lost or stolen money order', 'Making/receiving payments, sending money', 'Managing the line of credit', 'Managing the loan or lease', 'Managing, opening, or closing account', 'Money was not available when promised', 'Other', 'Other fee', 'Other service issues', 'Other transaction issues', 'Overdraft, savings or rewards features', 'Overlimit fee', 'Payment to acct not credited', 'Payoff process', 'Privacy', 'Problems caused by my funds being low', 'Problems when you are unable to pay', 'Received a loan I didn\'t apply for', 'Rewards', 'Sale of account', 'Settlement process and costs', 'Shopping for a line of credit', 'Shopping for a loan or lease', 'Taking out the loan or lease', 'Taking/threatening an illegal action', 'Transaction issue', 'Unable to get credit report/credit score', 'Unauthorized transactions/trans. issues', 'Unexpected/Other fees', 'Unsolicited issuance of credit card', 'Using a debit or ATM card', 'Wrong amount charged or received', 'Lender damaged or destroyed vehicle'
# 'product'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             'Bank account or service', 'Consumer Loan', 'Credit card', 'Credit reporting', 'Debt collection', 'Money transfers', 'Mortgage', 'Other financial service', 'Payday loan', 'Prepaid card', 'Student loan', 'Virtual currency'
# 'state'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               'AA', 'AK', 'AL', 'AP', 'AR', 'AS', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'FM', 'GA', 'GU', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MH', 'MI', 'MN', 'MO', 'MP', 'MS', 'MT', 'NC', 'ND', 'NE', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'VI', 'WA', 'WI', 'WV', 'WY', 'nan', 'AE', 'VT'
# 'sub_issue'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'Account status', 'Account terms', 'Account terms and changes', 'Attempted to collect wrong amount', 'Attempted to/Collected exempt funds', 'Billing dispute', 'Called after sent written cease of comm', 'Called outside of 8am-9pm', 'Can\'t decrease my monthly payments', 'Can\'t get flexible payment options', 'Can\'t qualify for a loan', 'Can\'t temporarily postpone payments', 'Contacted employer after asked not to', 'Contacted me after I asked not to', 'Contacted me instead of my attorney', 'Debt is not mine', 'Debt resulted from identity theft', 'Debt was discharged in bankruptcy', 'Debt was paid', 'Don\'t agree with fees charged', 'Frequent or repeated calls', 'Having problems with customer service', 'Impersonated an attorney or official', 'Inadequate help over the phone', 'Indicated committed crime not paying', 'Indicated shouldn\'t respond to lawsuit', 'Information is not mine', 'Investigation took too long', 'Keep getting calls about my loan', 'Need information about my balance/terms', 'No notice of investigation status/result', 'Not disclosed as an attempt to collect', 'Not given enough info to verify debt', 'Personal information', 'Problem cancelling or closing account', 'Problem getting my free annual report', 'Problem getting report or credit score', 'Problem with fraud alerts', 'Problem with statement of dispute', 'Public record', 'Qualify for a better loan than offered', 'Received bad information about my loan', 'Received marketing offer after opted out', 'Receiving unwanted marketing/advertising', 'Reinserted previously deleted info', 'Report improperly shared by CRC', 'Report shared with employer w/o consent', 'Right to dispute notice not received', 'Seized/Attempted to seize property', 'Sued w/o proper notification of suit', 'Sued where didn\'t live/sign for debt', 'Talked to a third party about my debt', 'Threatened arrest/jail if do not pay', 'Threatened to sue on too old debt', 'Threatened to take legal action', 'Trouble with how payments are handled', 'Used obscene/profane/abusive language', 'nan'
# 'sub_product'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              '(CD) Certificate of deposit', 'Auto', 'Cashing a check without an account', 'Check cashing', 'Checking account', 'Conventional adjustable mortgage (ARM)', 'Conventional fixed mortgage', 'Credit card', 'Credit repair', 'Debt settlement', 'Domestic (US) money transfer', 'Electronic Benefit Transfer / EBT card', 'FHA mortgage', 'Federal student loan', 'Federal student loan servicing', 'Foreign currency exchange', 'General purpose card', 'Gift or merchant card', 'Government benefit payment card', 'Home equity loan or line of credit', 'I do not know', 'ID prepaid card', 'Installment loan', 'International money transfer', 'Medical', 'Mobile wallet', 'Money order', 'Mortgage', 'Non-federal student loan', 'Other (i.e. phone, health club, etc.)', 'Other bank product/service', 'Other mortgage', 'Other special purpose card', 'Pawn loan', 'Payday loan', 'Payroll card', 'Personal line of credit', 'Refund anticipation check', 'Reverse mortgage', 'Savings account', 'Title loan', 'Transit card', 'Traveler’s/Cashier’s checks', 'VA mortgage', 'Vehicle lease', 'Vehicle loan', 'nan'
# 'timely_response'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       'No', 'Yes'

# %%
# 데이터셋 검증: 설정(+ 업데이트)된 스키마에 맞춰 통계를 검증한다. 피처 속성, skew, drift 임계치 등
# 설정에 의한 이상치 판단 결과를 확인할 수 있다.
example_validator = ExampleValidator(statistics=statistics_artifact,
                                     schema=schema_artifact)
context.run(example_validator)
context.show(example_validator)
# Out:
# ExampleValidator(spec: <tfx.types.standard_component_specs.ExampleValidatorSpec object at 0x7ff55cc2f2b0>, executor_spec: <tfx.dsl.components.base.executor_spec.ExecutorClassSpec object at 0x7ff55cc2f400>, driver_class: <class 'tfx.dsl.components.base.base_driver.BaseDriver'>, component_id: ExampleValidator, inputs: {'statistics': OutputChannel(artifact_type=ExampleStatistics, producer_component_id=StatisticsGen, output_key=statistics, additional_properties={}, additional_custom_properties={}), 'schema': OutputChannel(artifact_type=Schema, producer_component_id=SchemaGen, output_key=schema, additional_properties={}, additional_custom_properties={})}, outputs: {'anomalies': OutputChannel(artifact_type=ExampleAnomalies, producer_component_id=ExampleValidator, output_key=anomalies, additional_properties={}, additional_custom_properties={})})

# %%
anomalies_artifact = example_validator.outputs['anomalies']
context.show(anomalies_artifact)
# Out:
# <b>Artifact at /tmp/tfx-interactive-2023-01-11T06_57_02.948885-ch4kwyky/ExampleValidator/anomalies/8</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>
# <div><b>'eval' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>
